# %%
#GAME ON ROCK PAPER SCISSORS
choice_options=('y','Y','N','n')
choice=None

while choice not in choice_options:
  choice=input("Do You want to play again?\nPress y for yes(y) and n for no(n):")
ycount=0
ccount=0

options=('rock','paper','scissor')

if (choice=='y') or (choice=='Y'):
  print("WELCOME\n")


def score(comp,you):
    global ycount,ccount
    if a==True:
        ycount=+1
    elif a==False:
        ccount=+1
    else:
        ycount=+0
        ccount=+0
    print(f"YOUR SCORE:{ycount}")
    print(f"COMPUTER SCORE:{ccount}")
    ycount=ycount
    ccount=ccount




while(choice=='y') or (choice=='Y'):
    import random
    def game(comp,you):
        if comp==you:
            return None
        elif comp=='rock':
            if you=='paper':
                return True
            else:
                return False
        elif (comp=='scissor'):
            if (you=='rock'):
                return True
            else:
                return False
        elif (comp=='paper'):
            if (you=='scissor'):
                return True
            else:
                return False


    comp=random.randint(1,3)
    if (comp==1):
        comp='scissor'
    elif(comp==2):
        comp='paper'
    else:
        comp='rock'


    you=None
    while you not in options:
      you=input("Your chioice: (rock,paper,scissor)):")

    a= game(comp,you)

    if a==None:
        print('TIE')
    elif a==True:
        print('You Win!')
    else:
        print('You Lose')

    print(f'Computer chose:{comp}')
    print(f'You chose:{you}')

    score(comp,you)
    print("-----------------------------------------------------------------------------------------------------")
    choice=input("Do You want to play again? Yes(y),No(n):")



if (choice=='n' or choice=='N'):
  print("\nTHANKS FOR PLAYING! HOPE YOU HAD FUN!!")
# Out:
# Do You want to play again?
# Press y for yes(y) and n for no(n):y
# WELCOME
#
# Your chioice: (rock,paper,scissor)):rock
# You Lose
# Computer chose:paper
# You chose:rock
# YOUR SCORE:0
# COMPUTER SCORE:1
# -----------------------------------------------------------------------------------------------------
# Do You want to play again? Yes(y),No(n):y
# Your chioice: (rock,paper,scissor)):paper
# You Win!
# Computer chose:rock
# You chose:paper
# YOUR SCORE:1
# COMPUTER SCORE:1
# -----------------------------------------------------------------------------------------------------
# Do You want to play again? Yes(y),No(n):y
# Your chioice: (rock,paper,scissor)):rock
# TIE
# Computer chose:rock
# You chose:rock
# YOUR SCORE:0
# COMPUTER SCORE:0
# -----------------------------------------------------------------------------------------------------
# Do You want to play again? Yes(y),No(n):y
# Your chioice: (rock,paper,scissor)):paper
# You Lose
# Computer chose:scissor
# ...
